# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 2, 3, np.nan, 4, 5, 6], index = [1, 2, 3, 4, 5, 6, 7]) #struktur data series 1D
s
# Out:
# 1    1.0
# 2    2.0
# 3    3.0
# 4    NaN
# 5    4.0
# 6    5.0
# 7    6.0
# dtype: float64

# %%
nama = pd.Series(['Anas', 'Umul', 'Habibah', 'Rofiqoh', 'Salamah'], index = [1, 2, 3, 4, 5]) #struktur data series 1D
nama
# Out:
# 1       Anas
# 2       Umul
# 3    Habibah
# 4    Rofiqoh
# 5    Salamah
# dtype: object

# %%
dates = pd.date_range('20191211', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#                '2019-12-15', '2019-12-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
d = pd.date_range(start='12/11/2019', end='12/16/2019')

# %%
d
# Out:
# DatetimeIndex(['2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#                '2019-12-15', '2019-12-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20191211'),
   ...:                     'C': pd.Series(12, index=[1,2,3,4], dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'foo'})

df2
# Out:
#      A          B     C  D      E    F
# 1  1.0 2019-12-11  12.0  3   test  foo
# 2  1.0 2019-12-11  12.0  3  train  foo
# 3  1.0 2019-12-11  12.0  3   test  foo
# 4  1.0 2019-12-11  12.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head() #5 data teratas
# Out:
#                    A         B         C         D
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325

# %%
df.tail() #5 data teraktir
# Out:
#                    A         B         C         D
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df.tail(3) #3 data terakhir
# Out:
#                    A         B         C         D
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df.index
# Out:
# DatetimeIndex(['2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#                '2019-12-15', '2019-12-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df.values
# Out:
# array([[-1.17591688, -0.19507994, -1.3415806 , -0.45742654],
#        [ 1.40405749,  0.09622228,  0.09623684,  0.28729924],
#        [-0.26832517,  1.78480929, -0.32108147,  0.53965191],
#        [ 0.32785423, -0.17763957, -1.59868819,  0.01500154],
#        [ 1.07357852, -0.26215037,  0.43634533, -0.62832547],
#        [-0.09545479,  0.1747262 , -1.7411622 , -0.07815219]])

# %%
df2.values
# Out:
# array([[1.0, Timestamp('2019-12-11 00:00:00'), 12.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2019-12-11 00:00:00'), 12.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2019-12-11 00:00:00'), 12.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2019-12-11 00:00:00'), 12.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe() #shows a quick statistic summary of your data
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.210966  0.236815 -0.744988 -0.053659
# std    0.941094  0.778098  0.933809  0.439740
# min   -1.175917 -0.262150 -1.741162 -0.628325
# 25%   -0.225108 -0.190720 -1.534411 -0.362608
# 50%    0.116200 -0.040709 -0.831331 -0.031575
# 75%    0.887147  0.155100 -0.008093  0.219225
# max    1.404057  1.784809  0.436345  0.539652

# %%
df.T #transpose data
# Out:
#    2019-12-11  2019-12-12  2019-12-13  2019-12-14  2019-12-15  2019-12-16
# A   -1.175917    1.404057   -0.268325    0.327854    1.073579   -0.095455
# B   -0.195080    0.096222    1.784809   -0.177640   -0.262150    0.174726
# C   -1.341581    0.096237   -0.321081   -1.598688    0.436345   -1.741162
# D   -0.457427    0.287299    0.539652    0.015002   -0.628325   -0.078152

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2019-12-11 -0.457427 -1.341581 -0.195080 -1.175917
# 2019-12-12  0.287299  0.096237  0.096222  1.404057
# 2019-12-13  0.539652 -0.321081  1.784809 -0.268325
# 2019-12-14  0.015002 -1.598688 -0.177640  0.327854
# 2019-12-15 -0.628325  0.436345 -0.262150  1.073579
# 2019-12-16 -0.078152 -1.741162  0.174726 -0.095455

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652

# %%
df['A'] #selection - getting
# Out:
# 2019-12-11   -1.175917
# 2019-12-12    1.404057
# 2019-12-13   -0.268325
# 2019-12-14    0.327854
# 2019-12-15    1.073579
# 2019-12-16   -0.095455
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652

# %%
df['20191212':'20191215']
# Out:
#                    A         B         C         D
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325

# %%
df.loc[dates[0]] #selection by label/index
# Out:
# A   -1.175917
# B   -0.195080
# C   -1.341581
# D   -0.457427
# Name: 2019-12-11 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2019-12-11 -1.175917 -0.195080
# 2019-12-12  1.404057  0.096222
# 2019-12-13 -0.268325  1.784809
# 2019-12-14  0.327854 -0.177640
# 2019-12-15  1.073579 -0.262150
# 2019-12-16 -0.095455  0.174726

# %%
df.loc['20191213':'20191216', ['A', 'B']]
# Out:
#                    A         B
# 2019-12-13 -0.268325  1.784809
# 2019-12-14  0.327854 -0.177640
# 2019-12-15  1.073579 -0.262150
# 2019-12-16 -0.095455  0.174726

# %%
df.loc['20191214', ['A', 'B']]
# Out:
# A    0.327854
# B   -0.177640
# Name: 2019-12-14 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# -1.1759168811741028

# %%
df.at[dates[0], 'A']
# Out:
# -1.1759168811741028

# %%
df.iloc[3] #selection by position
# Out:
# A    0.327854
# B   -0.177640
# C   -1.598688
# D    0.015002
# Name: 2019-12-14 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2] #baris 3-5, kolom 0-2
# Out:
#                    A        B
# 2019-12-14  0.327854 -0.17764
# 2019-12-15  1.073579 -0.26215

# %%
df.iloc[1, 1]
# Out:
# 0.0962222797231733

# %%
df.iat[1,1]
# Out:
# 0.0962222797231733

# %%
df[df.B > 0] #boolean indexing
# Out:
#                    A         B         C         D
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2019-12-11       NaN       NaN       NaN       NaN
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13       NaN  1.784809       NaN  0.539652
# 2019-12-14  0.327854       NaN       NaN  0.015002
# 2019-12-15  1.073579       NaN  0.436345       NaN
# 2019-12-16       NaN  0.174726       NaN       NaN

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C         D
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2019-12-11 -1.175917 -0.195080 -1.341581 -0.457427    one
# 2019-12-12  1.404057  0.096222  0.096237  0.287299    one
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652    two
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002  three
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325   four
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152  three

# %%
df2[df2['E'].isin(['three', 'four'])]
# Out:
#                    A         B         C         D      E
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002  three
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325   four
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152  three

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20191211', periods=6)) #setting
s1
# Out:
# 2019-12-11    1
# 2019-12-12    2
# 2019-12-13    3
# 2019-12-14    4
# 2019-12-15    5
# 2019-12-16    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], 'A'] = 0
df
# Out:
#                    A         B         C         D
# 2019-12-11  0.000000 -0.195080 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df.iat[0, 1] = 0 #baris index ke-0 dan kolom index ke-1
df
# Out:
#                    A         B         C         D
# 2019-12-11  0.000000  0.000000 -1.341581 -0.457427
# 2019-12-12  1.404057  0.096222  0.096237  0.287299
# 2019-12-13 -0.268325  1.784809 -0.321081  0.539652
# 2019-12-14  0.327854 -0.177640 -1.598688  0.015002
# 2019-12-15  1.073579 -0.262150  0.436345 -0.628325
# 2019-12-16 -0.095455  0.174726 -1.741162 -0.078152

# %%
df.loc[:, 'D'] = np.array([5] * len(df) )
df
# Out:
#                    A         B         C  D
# 2019-12-11  0.000000  0.000000 -1.341581  5
# 2019-12-12  1.404057  0.096222  0.096237  5
# 2019-12-13 -0.268325  1.784809 -0.321081  5
# 2019-12-14  0.327854 -0.177640 -1.598688  5
# 2019-12-15  1.073579 -0.262150  0.436345  5
# 2019-12-16 -0.095455  0.174726 -1.741162  5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D
# 2019-12-11  0.000000  0.000000 -1.341581 -5
# 2019-12-12 -1.404057 -0.096222 -0.096237 -5
# 2019-12-13 -0.268325 -1.784809 -0.321081 -5
# 2019-12-14 -0.327854 -0.177640 -1.598688 -5
# 2019-12-15 -1.073579 -0.262150 -0.436345 -5
# 2019-12-16 -0.095455 -0.174726 -1.741162 -5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E']) #missing data
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    A         B         C  D    E
# 2019-12-11  0.000000  0.000000 -1.341581  5  1.0
# 2019-12-12  1.404057  0.096222  0.096237  5  1.0
# 2019-12-13 -0.268325  1.784809 -0.321081  5  NaN
# 2019-12-14  0.327854 -0.177640 -1.598688  5  NaN

# %%
df1.dropna(how='any')
df1
# Out:
#                    A         B         C  D    E
# 2019-12-11  0.000000  0.000000 -1.341581  5  1.0
# 2019-12-12  1.404057  0.096222  0.096237  5  1.0
# 2019-12-13 -0.268325  1.784809 -0.321081  5  NaN
# 2019-12-14  0.327854 -0.177640 -1.598688  5  NaN

# %%
df1.fillna(value=5) #mengisi nilai yang NaN
# Out:
#                    A         B         C  D    E
# 2019-12-11  0.000000  0.000000 -1.341581  5  1.0
# 2019-12-12  1.404057  0.096222  0.096237  5  1.0
# 2019-12-13 -0.268325  1.784809 -0.321081  5  5.0
# 2019-12-14  0.327854 -0.177640 -1.598688  5  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2019-12-11  False  False  False  False  False
# 2019-12-12  False  False  False  False  False
# 2019-12-13  False  False  False  False   True
# 2019-12-14  False  False  False  False   True

# %%
df.mean() #stats - rata-rata perkolom
# Out:
# A    0.406952
# B    0.269328
# C   -0.744988
# D    5.000000
# dtype: float64

# %%
df.mean(1) #rata-rata perbaris
# Out:
# 2019-12-11    0.914605
# 2019-12-12    1.649129
# 2019-12-13    1.548851
# 2019-12-14    0.887882
# 2019-12-15    1.561943
# 2019-12-16    0.834527
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates)
s.shift(2) #nilai digeser
# Out:
# 2019-12-11    NaN
# 2019-12-12    NaN
# 2019-12-13    1.0
# 2019-12-14    3.0
# 2019-12-15    5.0
# 2019-12-16    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D
# 2019-12-11  0.000000  0.000000 -1.341581  5
# 2019-12-12  1.404057  0.096222  0.096237  5
# 2019-12-13 -0.268325  1.784809 -0.321081  5
# 2019-12-14  0.327854 -0.177640 -1.598688  5
# 2019-12-15  1.073579 -0.262150  0.436345  5
# 2019-12-16 -0.095455  0.174726 -1.741162  5

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D
# 2019-12-11 -1.000000 -1.000000 -2.341581  4.0
# 2019-12-12 -1.595943 -2.903778 -2.903763  2.0
# 2019-12-13 -5.268325 -3.215191 -5.321081  0.0
# 2019-12-14       NaN       NaN       NaN  NaN
# 2019-12-15 -4.926421 -6.262150 -5.563655 -1.0
# 2019-12-16 -8.095455 -7.825274 -9.741162 -3.0

# %%
df.apply(np.cumsum) #apply
# Out:
#                    A         B         C   D
# 2019-12-11  0.000000  0.000000 -1.341581   5
# 2019-12-12  1.404057  0.096222 -1.245344  10
# 2019-12-13  1.135732  1.881032 -1.566425  15
# 2019-12-14  1.463587  1.703392 -3.165113  20
# 2019-12-15  2.537165  1.441242 -2.728768  25
# 2019-12-16  2.441710  1.615968 -4.469930  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.672383
# B    2.046960
# C    2.177508
# D    0.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10)) #histogramming
s
# Out:
# 0    2
# 1    5
# 2    3
# 3    0
# 4    0
# 5    3
# 6    6
# 7    4
# 8    4
# 9    1
# dtype: int32

# %%
s.value_counts()
# Out:
# 4    2
# 3    2
# 0    2
# 6    1
# 5    1
# 2    1
# 1    1
# dtype: int64

# %%
#string method
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4)) #merge
df
# Out:
#           0         1         2         3
# 0  1.503942  0.931552  0.371603 -0.178392
# 1 -1.259511 -0.048064  0.189607 -0.288215
# 2  1.046308  0.727332  0.868360  0.065877
# 3 -4.117259  0.462584  0.906429 -0.856605
# 4 -1.091305 -1.149434 -2.093874 -0.736348
# 5 -0.907710 -0.436184  0.912446  0.661654
# 6 -0.248752  0.133903 -0.279845 -1.822828
# 7 -0.082837 -0.925689 -1.650008 -1.814637
# 8 -0.433518 -0.344356  0.081560 -2.312786
# 9 -0.000208  1.208090  1.001435 -0.043799

# %%
pieces = [df[:3], df[3:7], df[7:]] #dipisah menjadi 3 tabel
pieces
# Out:
# [          0         1         2         3
#  0  1.503942  0.931552  0.371603 -0.178392
#  1 -1.259511 -0.048064  0.189607 -0.288215
#  2  1.046308  0.727332  0.868360  0.065877,
#            0         1         2         3
#  3 -4.117259  0.462584  0.906429 -0.856605
#  4 -1.091305 -1.149434 -2.093874 -0.736348
#  5 -0.907710 -0.436184  0.912446  0.661654
#  6 -0.248752  0.133903 -0.279845 -1.822828,
#            0         1         2         3
#  7 -0.082837 -0.925689 -1.650008 -1.814637
#  8 -0.433518 -0.344356  0.081560 -2.312786
#  9 -0.000208  1.208090  1.001435 -0.043799]

# %%
pd.concat(pieces) #disatukan menjadi satu tabel
# Out:
#           0         1         2         3
# 0  1.503942  0.931552  0.371603 -0.178392
# 1 -1.259511 -0.048064  0.189607 -0.288215
# 2  1.046308  0.727332  0.868360  0.065877
# 3 -4.117259  0.462584  0.906429 -0.856605
# 4 -1.091305 -1.149434 -2.093874 -0.736348
# 5 -0.907710 -0.436184  0.912446  0.661654
# 6 -0.248752  0.133903 -0.279845 -1.822828
# 7 -0.082837 -0.925689 -1.650008 -1.814637
# 8 -0.433518 -0.344356  0.081560 -2.312786
# 9 -0.000208  1.208090  1.001435 -0.043799

# %%
#Join
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key') #menyatukan menjadi 1 tabel
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D']) #append
df
# Out:
#           A         B         C         D
# 0  0.539969 -1.672121 -1.113861 -0.451138
# 1 -1.580917  2.206349 -0.946219  0.461814
# 2 -0.161256 -0.138166  0.173457  2.420706
# 3  1.476877  0.185738  0.160963  0.760881
# 4 -1.402912  1.118648  0.758233  2.940230
# 5  0.011509  1.744764 -0.509583 -1.836678
# 6  0.940417 -0.318932  0.039513  1.011678
# 7 -0.934435 -1.065947  0.768957  0.161461

# %%
s = df.iloc[3]
s
# Out:
# A    1.476877
# B    0.185738
# C    0.160963
# D    0.760881
# Name: 3, dtype: float64

# %%
df.append(s, ignore_index=True) #menambahkan s ke baris setelah terakhir
# Out:
#           A         B         C         D
# 0  0.539969 -1.672121 -1.113861 -0.451138
# 1 -1.580917  2.206349 -0.946219  0.461814
# 2 -0.161256 -0.138166  0.173457  2.420706
# 3  1.476877  0.185738  0.160963  0.760881
# 4 -1.402912  1.118648  0.758233  2.940230
# 5  0.011509  1.744764 -0.509583 -1.836678
# 6  0.940417 -0.318932  0.039513  1.011678
# 7 -0.934435 -1.065947  0.768957  0.161461
# 8  1.476877  0.185738  0.160963  0.760881

# %%
#grouping
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                             'foo', 'bar', 'foo', 'foo'],
                       'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                       'D': np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.900149  0.482494
# 1  bar    one  0.335252  1.128756
# 2  foo    two -0.577649 -1.378548
# 3  bar  three  1.911876  1.163472
# 4  foo    two -0.189758  1.404909
# 5  bar    two -1.326248  0.279864
# 6  foo    one  0.127000  0.015005
# 7  foo  three  0.107806 -0.520374

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.920880  2.572092
# foo -1.432751  0.003487

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.335252  1.128756
#     three  1.911876  1.163472
#     two   -1.326248  0.279864
# foo one   -0.773149  0.497499
#     three  0.107806 -0.520374
#     two   -0.767407  0.026362

# %%
#reshaping
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                         'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                         'one', 'two', 'one', 'two']]))

tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.855352 -0.074057
#       two     1.006149  0.748521
# baz   one    -0.533298 -0.775998
#       two     1.173924  1.400773

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.855352
#                B   -0.074057
#        two     A    1.006149
#                B    0.748521
# baz    one     A   -0.533298
#                B   -0.775998
#        two     A    1.173924
#                B    1.400773
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.855352 -0.074057
#       two     1.006149  0.748521
# baz   one    -0.533298 -0.775998
#       two     1.173924  1.400773

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.855352  1.006149
#       B -0.074057  0.748521
# baz   A -0.533298  1.173924
#       B -0.775998  1.400773

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.855352 -0.533298
#        B -0.074057 -0.775998
# two    A  1.006149  1.173924
#        B  0.748521  1.400773

# %%
#pivot table
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                       'E': np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.182299  0.261973
# 1     one  B  foo  0.440341  0.138123
# 2     two  C  foo -0.970528  1.135362
# 3   three  A  bar -0.364731 -0.048705
# 4     one  B  bar  0.626740 -1.379105
# 5     one  C  bar -0.313752 -0.574882
# 6     two  A  foo  0.317777 -0.142573
# 7   three  B  foo  1.422775 -1.738008
# 8     one  C  foo -1.807674 -1.582808
# 9     one  A  bar -2.019699 -1.107782
# 10    two  B  bar -0.046867 -0.767093
# 11  three  C  bar -0.839537  1.402843

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -2.019699  0.182299
#       B  0.626740  0.440341
#       C -0.313752 -1.807674
# three A -0.364731       NaN
#       B       NaN  1.422775
#       C -0.839537       NaN
# two   A       NaN  0.317777
#       B -0.046867       NaN
#       C       NaN -0.970528

# %%
#time series
rng = pd.date_range('12/11/2019', periods=100, freq='S')

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample('5Min').sum()
# Out:
# 2019-12-11    24424
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('12/11/2012 00:00', periods=5, freq='D')

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-12-11   -0.257229
# 2012-12-12   -0.603431
# 2012-12-13    1.538311
# 2012-12-14    0.197779
# 2012-12-15    1.270026
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-12-11 00:00:00+00:00   -0.257229
# 2012-12-12 00:00:00+00:00   -0.603431
# 2012-12-13 00:00:00+00:00    1.538311
# 2012-12-14 00:00:00+00:00    0.197779
# 2012-12-15 00:00:00+00:00    1.270026
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-12-10 19:00:00-05:00   -0.257229
# 2012-12-11 19:00:00-05:00   -0.603431
# 2012-12-12 19:00:00-05:00    1.538311
# 2012-12-13 19:00:00-05:00    0.197779
# 2012-12-14 19:00:00-05:00    1.270026
# Freq: D, dtype: float64

# %%
#plotting
ts = pd.Series(np.random.randn(1000),
                   index=pd.date_range('12/11/2000', periods=1000))

# %%
ts = ts.cumsum()
ts.plot()

# %%
import matplotlib.pyplot as plt
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                      columns=['A', 'B', 'C', 'D'])
    

df = df.cumsum()

plt.figure()

df.plot()

plt.legend(loc='best')

# %%
df
# Out:
#                     A          B          C          D
# 2000-12-11   0.664836   0.492608   1.739331   2.003522
# 2000-12-12   0.296302   0.220682   2.668047   3.677491
# 2000-12-13   0.377902   0.474060   2.181530   4.944407
# 2000-12-14   2.169402   0.200989   2.575537   6.188476
# 2000-12-15   1.803539   0.439428   3.993926   7.036980
# 2000-12-16   1.776753   2.256232   3.692034   6.722109
# 2000-12-17  -0.371101   2.492924   3.937774   5.726130
# 2000-12-18  -0.781758   2.624783   3.650397   5.187270
# 2000-12-19  -2.289469   1.973884   3.846509   3.487281
# 2000-12-20  -3.173022   0.114740   3.407850   2.935693
# 2000-12-21  -2.582325  -0.759283   2.330630   4.474983
# 2000-12-22  -4.136276  -0.307642   1.857510   4.910770
# 2000-12-23  -5.437854   0.409065   2.427747   4.683382
# 2000-12-24  -3.609341   1.764959   3.073834   2.919276
# 2000-12-25  -3.863574   1.975663   1.565587   1.663757
# 2000-12-26  -1.853315   1.397009   0.530490   1.488146
# ...

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-12-11   0.664836   0.492608   1.739331   2.003522
# 1    2000-12-12   0.296302   0.220682   2.668047   3.677491
# 2    2000-12-13   0.377902   0.474060   2.181530   4.944407
# 3    2000-12-14   2.169402   0.200989   2.575537   6.188476
# 4    2000-12-15   1.803539   0.439428   3.993926   7.036980
# 5    2000-12-16   1.776753   2.256232   3.692034   6.722109
# 6    2000-12-17  -0.371101   2.492924   3.937774   5.726130
# 7    2000-12-18  -0.781758   2.624783   3.650397   5.187270
# 8    2000-12-19  -2.289469   1.973884   3.846509   3.487281
# 9    2000-12-20  -3.173022   0.114740   3.407850   2.935693
# 10   2000-12-21  -2.582325  -0.759283   2.330630   4.474983
# 11   2000-12-22  -4.136276  -0.307642   1.857510   4.910770
# 12   2000-12-23  -5.437854   0.409065   2.427747   4.683382
# 13   2000-12-24  -3.609341   1.764959   3.073834   2.919276
# 14   2000-12-25  -3.863574   1.975663   1.565587   1.663757
# ...

# %%
df.to_hdf('foo.h5', 'df')

# %%
pd.read_hdf('foo.h5', 'df')
# Out:
#                     A          B          C          D
# 2000-12-11   0.664836   0.492608   1.739331   2.003522
# 2000-12-12   0.296302   0.220682   2.668047   3.677491
# 2000-12-13   0.377902   0.474060   2.181530   4.944407
# 2000-12-14   2.169402   0.200989   2.575537   6.188476
# 2000-12-15   1.803539   0.439428   3.993926   7.036980
# 2000-12-16   1.776753   2.256232   3.692034   6.722109
# 2000-12-17  -0.371101   2.492924   3.937774   5.726130
# 2000-12-18  -0.781758   2.624783   3.650397   5.187270
# 2000-12-19  -2.289469   1.973884   3.846509   3.487281
# 2000-12-20  -3.173022   0.114740   3.407850   2.935693
# 2000-12-21  -2.582325  -0.759283   2.330630   4.474983
# 2000-12-22  -4.136276  -0.307642   1.857510   4.910770
# 2000-12-23  -5.437854   0.409065   2.427747   4.683382
# 2000-12-24  -3.609341   1.764959   3.073834   2.919276
# 2000-12-25  -3.863574   1.975663   1.565587   1.663757
# 2000-12-26  -1.853315   1.397009   0.530490   1.488146
# ...

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#                     A          B          C          D
# 2000-12-11   0.664836   0.492608   1.739331   2.003522
# 2000-12-12   0.296302   0.220682   2.668047   3.677491
# 2000-12-13   0.377902   0.474060   2.181530   4.944407
# 2000-12-14   2.169402   0.200989   2.575537   6.188476
# 2000-12-15   1.803539   0.439428   3.993926   7.036980
# 2000-12-16   1.776753   2.256232   3.692034   6.722109
# 2000-12-17  -0.371101   2.492924   3.937774   5.726130
# 2000-12-18  -0.781758   2.624783   3.650397   5.187270
# 2000-12-19  -2.289469   1.973884   3.846509   3.487281
# 2000-12-20  -3.173022   0.114740   3.407850   2.935693
# 2000-12-21  -2.582325  -0.759283   2.330630   4.474983
# 2000-12-22  -4.136276  -0.307642   1.857510   4.910770
# 2000-12-23  -5.437854   0.409065   2.427747   4.683382
# 2000-12-24  -3.609341   1.764959   3.073834   2.919276
# 2000-12-25  -3.863574   1.975663   1.565587   1.663757
# 2000-12-26  -1.853315   1.397009   0.530490   1.488146
# ...
